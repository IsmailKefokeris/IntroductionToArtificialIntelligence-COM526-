# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv("netflix_data.csv")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
fig = px.bar(df, x='country', y='duration')
fig.show()
# Out:
# <div>                            <div id="c5765f36-67a7-4025-9978-657e6a4d71e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5765f36-67a7-4025-9978-657e6a4d71e0")) {                    Plotly.newPlot(                        "c5765f36-67a7-4025-9978-657e6a4d71e0",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>duration=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Brazil","Mexico","Singapore","United States","United States","Turkey","Egypt","United States","India","India","United States","Poland","Mexico","Thailand","United States","Nigeria",null,"Norway","India","U
# ...
